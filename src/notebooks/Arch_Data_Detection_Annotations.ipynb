# %% [markdown]
# # Arch Data Detection and Annotations
#
# In this notebook, we show how to load data from the **Arch-Dataset** and how to overlay the bounding box annotations for person detection.

# %%
import os
import sys

import numpy as np
import torch
from matplotlib import pyplot as plt

sys.path.append("..")

from data.ArchDataset import ArchDataset
from lib.visualizations import visualize_image, visualize_bbox

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Loading and Inspecting Dataset

# %%
arch_dataset = ArchDataset()
print(f"Arch-Dataset containing {len(arch_dataset)} images.")
# Out:
# Arch-Dataset containing 1366 images.

# %%
# idx = 0
idx = np.random.randint(low=0, high=len(arch_dataset))

img, meta = arch_dataset[idx]
print(f"Loaded image: {meta['image_name']}")
# Out:
# Loaded image: wm0563.jpg

# %%
visualize_image(img=img, preprocess=True, title=meta["image_name"])

# %%
visualize_bbox(img=img, boxes=meta["targets"]["boxes"], labels=meta["targets"]["arch_labels_str"], preprocess=True)

# %%
meta["targets"]["arch_labels_str"]
# Out:
# ['Heracles', 'bull', 'wrestling (mythological)']

# %% [markdown]
# <div class=alert style="background-color:#F5F5F5; border-color:#C8C8C8">
#    This notebook was created by <b>Angel Villar-Corrales</b>
# </div>
